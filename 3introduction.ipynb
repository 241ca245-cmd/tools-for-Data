# %% [markdown]
# ## Introduction
#
# This notebook provides an overview of data science tools, programming languages, libraries, and basic arithmetic operations commonly used in the field of data science.
